# %%
import os
import time
import datetime
from shutil import copyfile
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import xarray as xr
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import json
import copy
from torchvision.utils import make_grid
from torch.utils.data import Dataset
from torchvision import transforms
import torchvision.models as models
from torch.utils.data import DataLoader

# %%
BASE_PATH_DATA = 'data/skogsstyrelsen/'
BAND_NAMES = ['b01', 'b02', 'b03', 'b04', 'b05', 'b06', 'b07', 'b08', 'b8a', 'b09', 'b11', 'b12']

# %%
# Read data + corresponding json info (incl ground truth)
img_paths_train = list(np.load(os.path.join(BASE_PATH_DATA, 'skogs_names_train.npy')))
img_paths_train = [path[1:] for path in img_paths_train]

img_paths_val = list(np.load(os.path.join(BASE_PATH_DATA, 'skogs_names_val.npy')))
img_paths_val = [path[1:] for path in img_paths_val]

img_paths_test = list(np.load(os.path.join(BASE_PATH_DATA, 'skogs_names_test.npy')))
img_paths_test = [path[1:] for path in img_paths_test]

json_content_train = list(np.load(os.path.join(BASE_PATH_DATA, 'skogs_json_train.npy'), allow_pickle=True))
json_content_val = list(np.load(os.path.join(BASE_PATH_DATA, 'skogs_json_val.npy'), allow_pickle=True))
json_content_test = list(np.load(os.path.join(BASE_PATH_DATA, 'skogs_json_test.npy'), allow_pickle=True))

train_label = list(np.load(os.path.join(BASE_PATH_DATA, "skogs_gts_train.npy")))
val_label = list(np.load(os.path.join(BASE_PATH_DATA, "skogs_gts_val.npy")))
test_label = list(np.load(os.path.join(BASE_PATH_DATA, "skogs_gts_test.npy")))

# %%
print(f'train size = {len(img_paths_train)}')
print(f'val size = {len(img_paths_val)}')
print(f'test size = {len(img_paths_test)}')
# Out:
# train size = 260
# val size = 72
# test size = 100

# %%
# plot distribution of each data set
labels = ["clear", "cloudy"]
labels_num = [0,1]
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(10,5))

# Bar for training
cloudy = np.count_nonzero(train_label)
clear = len(train_label) - cloudy
ax1.bar(labels_num, [clear,cloudy])
ax1.set_xticks(labels_num, labels)
ax1.set_title("Distribution of training set")
ylim = ax1.get_ylim()

# Bar for validation
cloudy = np.count_nonzero(val_label)
clear = len(val_label) - cloudy
ax2.bar(labels_num, [clear,cloudy])
ax2.set_xticks(labels_num, labels)
ax2.set_title("Distribution of validation set")
ax2.set_ylim(ylim)

# Bar for testing
cloudy = np.count_nonzero(test_label)
clear = len(test_label) - cloudy
ax3.bar(labels_num, [clear,cloudy])
ax3.set_xticks(labels_num, labels)
ax3.set_title("Distribution of test set")
ax3.set_ylim(ylim)
# Out:
# (0.0, 197.4)

# %%
def load_image(path):
    img = xr.open_dataset(path)
    yy_mm_dd = getattr(img, 'time').values[0]
    yy = yy_mm_dd.astype('datetime64[Y]').astype(int) + 1970
    mm = yy_mm_dd.astype('datetime64[M]').astype(int) % 12 + 1

    band_list = []
    for band in BAND_NAMES:
        if yy >= 2022 and mm >= 1: # New normalization after Jan 2022
            band_list.append((getattr(img, band).values - 1000) / 10000)
        else:
            band_list.append(getattr(img, band).values / 10000) 
            
    img = np.concatenate(band_list, axis = 0)
    img = np.transpose(img, [1,2,0])
    img = np.fliplr(img).copy()
    img = np.flipud(img).copy()

    H, W = img.shape[:2]
        
    # padding
    if H != 21 and W != 21:
        zeros = np.zeros((1, 20, 12))
        img = np.concatenate((img, zeros), axis = 0)
        zeros = np.zeros((21, 1, 12))
        img = np.concatenate((img, zeros[:]), axis = 1)
        
    elif H != 21:
        zeros = np.zeros((1, 21, 12))
        img = np.concatenate((img, zeros), axis = 0)
        
    elif W != 21:
        zeros = np.zeros((21, 1, 12))
        img = np.concatenate((img, zeros[:]), axis = 1)
        

    return img

# %%
# incase we want to use a Dataloader, we could use this
class CustomImageDataset(Dataset):
    def __init__(self, label_dir, img_dir, transform=None, target_transform=None):
        self.img_labels = list(np.load(label_dir))
        self.img_dir = img_dir
        image_paths = list(np.load(img_dir))
        self.image_paths = [path[1:] for path in image_paths]
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        image = load_image(self.image_paths[idx])
        
        # convert to float32
        image = np.float32(image)
        label = self.img_labels[idx]

        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, label

# %%
from torch.utils.data import WeightedRandomSampler

BATCH_SIZE = 10
SHUFFLE = False

train_data = CustomImageDataset(os.path.join(BASE_PATH_DATA, "skogs_gts_train.npy"), os.path.join(BASE_PATH_DATA, 'skogs_names_train.npy'), transform=transforms.ToTensor())
labels = train_data.img_labels
class_sample_count = np.array(
    [len(np.where(labels == t)[0]) for t in np.unique(labels)])

weight = 1. / class_sample_count
samples_weight = np.array([weight[t] for t in labels])

samples_weight = torch.from_numpy(samples_weight)
sampler = WeightedRandomSampler(samples_weight.type('torch.DoubleTensor'), len(samples_weight))

train_loader = DataLoader(train_data, batch_size=len(train_data), shuffle=SHUFFLE, sampler=sampler)

val_data = CustomImageDataset(os.path.join(BASE_PATH_DATA, "skogs_gts_val.npy"), os.path.join(BASE_PATH_DATA, 'skogs_names_val.npy'), transform=transforms.ToTensor())
val_loader = DataLoader(val_data, batch_size=len(val_data), shuffle=SHUFFLE)

test_data = CustomImageDataset(os.path.join(BASE_PATH_DATA, "skogs_gts_test.npy"), os.path.join(BASE_PATH_DATA, 'skogs_names_test.npy'), transform=transforms.ToTensor())
test_loader = DataLoader(test_data, batch_size=len(test_data), shuffle=SHUFFLE)

# %%
# showing the first batch when using tensors
def show_batch(dl): 
    for images,lables in dl: 
        rgb_img = images[:, [3,2,1], :, :]/torch.max(images[:, [3,2,1], :, :])
        list_img = [img for img in rgb_img]
        Grid = make_grid(list_img, nrow=5)
        img = transforms.ToPILImage()(Grid) 
        img.show() 
        break
        
# show first batch of train data
# show_batch(train_loader)

# %%
# train model function
def train_model(model, criterion, optimizer, train_loader, val_loader, num_epochs = 10, show_plot = True):
    
    min_loss = 10000
    
    # Track loss
    training_loss, validation_loss = [], []
    
    # Track accuracy
    training_acc, validation_acc = [], []
    
    for i in range(num_epochs):
        # Track loss
        epoch_training_loss, epoch_validation_loss = 0, 0
        train_size, val_size = 0, 0
        
        # track accuracy
        train_correct, val_correct = 0, 0

        # training
        model.train(True)
        for batch_nr, (data, labels) in enumerate(train_loader):
            # predict
            pred = model(data)
            pred = torch.squeeze(pred)

            # calculate accuracy
            preds = torch.sigmoid(pred) >= 0.5
            
            train_correct += torch.sum(preds==labels).item()
            
            # Clear stored gradient values
            optimizer.zero_grad()
            loss = criterion(pred, labels.float())
            
            # Backpropagate the loss through the network to find the gradients of all parameters
            loss.backward()
            
            # Update the parameters along their gradients
            optimizer.step()
            
            # Update loss
            epoch_training_loss += loss.detach().numpy()
            train_size += len(data)
            
        # validation
        model.eval()
        for batch_nr, (data, labels) in enumerate(val_loader):
            
            # predict
            pred = model(data)
            pred = torch.squeeze(pred)
            
            # calculate accuracy
            preds = torch.sigmoid(pred) >= 0.5
            
            val_correct += torch.sum(preds==labels).item()
             
            # calculate loss
            loss = criterion(pred, labels.float())
            
            # check if loss is smaller than before, if so safe model
            if loss<min_loss:
                torch.save(model, 'best_model.pt')
                min_loss = loss
            
            # Update loss
            epoch_validation_loss += loss.detach().numpy()
            val_size += len(data)
            
        # Save loss for plot
        training_loss.append(epoch_training_loss/train_size)
        validation_loss.append(epoch_validation_loss/val_size)
        
        # Save accuracy for plot
        training_acc.append(train_correct/train_size)
        validation_acc.append(val_correct/val_size)

        # Print loss every 5 epochs
        #if i % 5 == 0:
        print(f'Epoch {i}, training loss: {training_loss[-1]}, validation loss: {validation_loss[-1]}')
        print(f'Train accuracy = {train_correct/train_size}')
        print(f'Validation accuracy = {val_correct/val_size}')

        torch.save(model, 'latest_model.pt')
        
    if show_plot:
        # Plot training and validation loss
        epoch = np.arange(len(training_loss))
        plt.figure(figsize=(8,4), dpi=100)
        plt.plot(epoch, training_loss, 'r', label='Training loss',)
        plt.plot(epoch, validation_loss, 'b', label='Validation loss')
        plt.legend()
        plt.xlabel('Epoch'), plt.ylabel('Loss')
        plt.show()
        
        # Plot training and validation accuracy
        plt.figure(figsize=(8,4), dpi=100)
        plt.plot(epoch, training_acc, 'r', label='Training accuracy',)
        plt.plot(epoch, validation_acc, 'b', label='Validation accuracy')
        plt.legend()
        plt.xlabel('Epoch'), plt.ylabel('Accuracy')
        plt.show()

# %%
# Hyperparams
LEARNING_RATE = 0.01
EPOCHS = 100

# define network
network = models.resnet18(num_classes = 1)
network.conv1 = nn.Conv2d(12, 64, kernel_size=3, stride=1, padding=5, bias=False) # 12 bands = 12 input channels

# define loss
loss_function = torch.nn.BCEWithLogitsLoss()
# define optimizer
optimizer = torch.optim.Adam(network.parameters(), lr=LEARNING_RATE)

train_model(network, loss_function, optimizer, train_loader, val_loader, EPOCHS)
# Out:
# Epoch 0, training loss: 0.0027997706945125872, validation loss: 680.3195529513889
# Train accuracy = 0.45384615384615384
# Validation accuracy = 0.2777777777777778
# Epoch 1, training loss: 0.007416691688390879, validation loss: 17191.43576388889
# Train accuracy = 0.5192307692307693
# Validation accuracy = 0.7222222222222222
# Epoch 2, training loss: 0.0037694674271803634, validation loss: 21494.45138888889
# Train accuracy = 0.4576923076923077
# Validation accuracy = 0.2777777777777778
# Epoch 3, training loss: 0.0022345992235037, validation loss: 3530.8611111111113
# Train accuracy = 0.6884615384615385
# Validation accuracy = 0.2777777777777778
# Epoch 4, training loss: 0.0023272812366485597, validation loss: 1458.6178385416667
# Train accuracy = 0.7576923076923077
# Validation accuracy = 0.2777777777777778
# Epoch 5, training loss: 0.0022289257783156173, validation loss: 533.8599717881945
# Train accuracy = 0.6884615384615385
# Validation accuracy = 0.2777777777777778
# Epoch 6, training loss: 0.002132650063588069, validation loss: 176.39910210503473
# Train accuracy = 0.7153846153846154
# Validation accuracy = 0.2777777777777778
# Epoch 7, training loss: 0.0021910768288832443, validation loss: 64.47056749131944
# Train accuracy = 0.6615384615384615
# Validation accuracy = 0.2777777777777778
# Epoch 8, training loss: 0.0019874898286966177, validation loss: 25.861590915256077
# Train accuracy = 0.8384615384615385
# Validation accuracy = 0.2777777777777778
# Epoch 9, training loss: 0.001994706804935749, validation loss: 11.688886006673178
# Train accuracy = 0.7769230769230769
# Validation accuracy = 0.2777777777777778
# Epoch 10, training loss: 0.0018454975806749783, validation loss: 5.955480363633898
# Train accuracy = 0.8192307692307692
# Validation accuracy = 0.2777777777777778
# Epoch 11, training loss: 0.001832883174602802, validation loss: 2.648045857747396
# Train accuracy = 0.8346153846153846
# Validation accuracy = 0.3055555555555556
# Epoch 12, training loss: 0.0016842798544810368, validation loss: 1.1242285834418402
# Train accuracy = 0.7884615384615384
# Validation accuracy = 0.375
# Epoch 13, training loss: 0.0014811845926138072, validation loss: 0.6630295117696127
# Train accuracy = 0.8846153846153846
# Validation accuracy = 0.3194444444444444
# Epoch 14, training loss: 0.001257847249507904, validation loss: 0.36213665538363987
# Train accuracy = 0.85
# Validation accuracy = 0.2916666666666667
# Epoch 15, training loss: 0.0016163121049220745, validation loss: 0.7224069701300727
# Train accuracy = 0.8076923076923077
# Validation accuracy = 0.2777777777777778
# Epoch 16, training loss: 0.0013296343959294833, validation loss: 0.9259016248914931
# Train accuracy = 0.8384615384615385
# Validation accuracy = 0.2777777777777778
# Epoch 17, training loss: 0.0015572809256040132, validation loss: 0.3630185392167833
# Train accuracy = 0.8538461538461538
# Validation accuracy = 0.2777777777777778
# Epoch 18, training loss: 0.0011994069585433372, validation loss: 0.14193342791663277
# Train accuracy = 0.85
# Validation accuracy = 0.3055555555555556
# Epoch 19, training loss: 0.0015545582542052635, validation loss: 0.2785058551364475
# Train accuracy = 0.8
# Validation accuracy = 0.2777777777777778
# Epoch 20, training loss: 0.0011577702485598051, validation loss: 0.48153818978203666
# Train accuracy = 0.8576923076923076
# Validation accuracy = 0.2777777777777778
# Epoch 21, training loss: 0.0012041189349614658, validation loss: 0.41615332497490776
# Train accuracy = 0.85
# Validation accuracy = 0.2777777777777778
# Epoch 22, training loss: 0.0012118571079694307, validation loss: 0.22888284259372288
# Train accuracy = 0.8192307692307692
# Validation accuracy = 0.2777777777777778
# Epoch 23, training loss: 0.0009538171956172357, validation loss: 0.06949341959423488
# Train accuracy = 0.8884615384615384
# Validation accuracy = 0.4583333333333333
# Epoch 24, training loss: 0.0009173804750809303, validation loss: 0.021561377578311496
# Train accuracy = 0.8807692307692307
# Validation accuracy = 0.7083333333333334
# Epoch 25, training loss: 0.001016855354492481, validation loss: 0.016444072127342224
# Train accuracy = 0.8846153846153846
# Validation accuracy = 0.8194444444444444
# Epoch 26, training loss: 0.000822289173419659, validation loss: 0.019060760736465454
# Train accuracy = 0.9038461538461539
# Validation accuracy = 0.8333333333333334
# Epoch 27, training loss: 0.00112867527283155, validation loss: 0.035332543982399836
# Train accuracy = 0.8538461538461538
# Validation accuracy = 0.6388888888888888
# Epoch 28, training loss: 0.0005772234155581548, validation loss: 0.05950380033916897
# Train accuracy = 0.9461538461538461
# Validation accuracy = 0.4861111111111111
# Epoch 29, training loss: 0.0008534913452771994, validation loss: 0.06424206495285034
# Train accuracy = 0.8884615384615384
# Validation accuracy = 0.3888888888888889
# Epoch 30, training loss: 0.0007589723055179303, validation loss: 0.043568306499057345
# Train accuracy = 0.9115384615384615
# Validation accuracy = 0.5
# Epoch 31, training loss: 0.0006398142530367924, validation loss: 0.06170594029956394
# Train accuracy = 0.9307692307692308
# Validation accuracy = 0.3472222222222222
# Epoch 32, training loss: 0.0004479214549064636, validation loss: 0.07107003529866536
# Train accuracy = 0.9576923076923077
# Validation accuracy = 0.3055555555555556
# Epoch 33, training loss: 0.0007187288541060227, validation loss: 0.05276900860998365
# Train accuracy = 0.926923076923077
# Validation accuracy = 0.4166666666666667
# Epoch 34, training loss: 0.0009695188357279851, validation loss: 0.01515301399760776
# Train accuracy = 0.9038461538461539
# Validation accuracy = 0.7777777777777778
# Epoch 35, training loss: 0.0006154722892321073, validation loss: 0.015939830078019038
# Train accuracy = 0.926923076923077
# Validation accuracy = 0.75
# Epoch 36, training loss: 0.000545892807153555, validation loss: 0.0304115977552202
# Train accuracy = 0.9423076923076923
# Validation accuracy = 0.5694444444444444
# Epoch 37, training loss: 0.0007400105778987592, validation loss: 0.07849409845140246
# Train accuracy = 0.9115384615384615
# Validation accuracy = 0.3194444444444444
# Epoch 38, training loss: 0.0007640449473491082, validation loss: 0.05435582002003988
# Train accuracy = 0.9115384615384615
# Validation accuracy = 0.3055555555555556
# Epoch 39, training loss: 0.0004865320256123176, validation loss: 0.0392860472202301
# Train accuracy = 0.9653846153846154
# Validation accuracy = 0.375
# Epoch 40, training loss: 0.0007074875327257009, validation loss: 0.02124287188053131
# Train accuracy = 0.8884615384615384
# Validation accuracy = 0.5694444444444444
# Epoch 41, training loss: 0.0007919114942734058, validation loss: 0.006329835289054447
# Train accuracy = 0.8846153846153846
# Validation accuracy = 0.8472222222222222
# Epoch 42, training loss: 0.000488298787520482, validation loss: 0.004067632887098525
# Train accuracy = 0.95
# Validation accuracy = 0.8888888888888888
# Epoch 43, training loss: 0.000464752631691786, validation loss: 0.004822902795341279
# Train accuracy = 0.9576923076923077
# Validation accuracy = 0.8611111111111112
# Epoch 44, training loss: 0.0005026307243567247, validation loss: 0.01120368887980779
# Train accuracy = 0.9384615384615385
# Validation accuracy = 0.8055555555555556
# Epoch 45, training loss: 0.000490333942266611, validation loss: 0.009726586441198984
# Train accuracy = 0.9615384615384616
# Validation accuracy = 0.8333333333333334
# Epoch 46, training loss: 0.0003963924657839995, validation loss: 0.009962375793192122
# Train accuracy = 0.95
# Validation accuracy = 0.8333333333333334
# Epoch 47, training loss: 0.00046973661161386047, validation loss: 0.0216355390018887
# Train accuracy = 0.9461538461538461
# Validation accuracy = 0.6805555555555556
# Epoch 48, training loss: 0.00033267770822231583, validation loss: 0.029358949926164415
# Train accuracy = 0.9769230769230769
# Validation accuracy = 0.6111111111111112
# Epoch 49, training loss: 0.00028134283538048085, validation loss: 0.024755939841270447
# Train accuracy = 0.9730769230769231
# Validation accuracy = 0.6944444444444444
# Epoch 50, training loss: 0.00044663998369987197, validation loss: 0.0057481080293655396
# Train accuracy = 0.9576923076923077
# Validation accuracy = 0.8611111111111112
# Epoch 51, training loss: 0.0006413973294771635, validation loss: 0.01363155742486318
# Train accuracy = 0.9423076923076923
# Validation accuracy = 0.8055555555555556
# Epoch 52, training loss: 0.0010866009272061862, validation loss: 0.006263069808483124
# Train accuracy = 0.8846153846153846
# Validation accuracy = 0.8888888888888888
# Epoch 53, training loss: 0.0005395611891379724, validation loss: 0.008662008576922946
# Train accuracy = 0.9346153846153846
# Validation accuracy = 0.8611111111111112
# Epoch 54, training loss: 0.0004226525242512043, validation loss: 0.02071579959657457
# Train accuracy = 0.9384615384615385
# Validation accuracy = 0.6666666666666666
# Epoch 55, training loss: 0.00036048444990928355, validation loss: 0.028026541074117024
# Train accuracy = 0.9576923076923077
# Validation accuracy = 0.4722222222222222
# Epoch 56, training loss: 0.000605695121563398, validation loss: 0.016586596767107647
# Train accuracy = 0.9307692307692308
# Validation accuracy = 0.5972222222222222
# Epoch 57, training loss: 0.0006247887244591346, validation loss: 0.017111207048098247
# Train accuracy = 0.9461538461538461
# Validation accuracy = 0.625
# Epoch 58, training loss: 0.0006286011865505805, validation loss: 0.02737125919924842
# Train accuracy = 0.9384615384615385
# Validation accuracy = 0.5555555555555556
# Epoch 59, training loss: 0.00046676514813533197, validation loss: 0.02961832947201199
# Train accuracy = 0.9538461538461539
# Validation accuracy = 0.5138888888888888
# Epoch 60, training loss: 0.0005586885488950289, validation loss: 0.02222235169675615
# Train accuracy = 0.9461538461538461
# Validation accuracy = 0.5833333333333334
# Epoch 61, training loss: 0.00046571882871481086, validation loss: 0.019051558441585965
# Train accuracy = 0.9461538461538461
# Validation accuracy = 0.625
# Epoch 62, training loss: 0.0004111463920428203, validation loss: 0.019589616192711726
# Train accuracy = 0.9615384615384616
# Validation accuracy = 0.625
# Epoch 63, training loss: 0.0004936313399901757, validation loss: 0.04260965519481235
# Train accuracy = 0.9423076923076923
# Validation accuracy = 0.3611111111111111
# Epoch 64, training loss: 0.00039745182372056523, validation loss: 0.06804032458199395
# Train accuracy = 0.9653846153846154
# Validation accuracy = 0.3194444444444444
# Epoch 65, training loss: 0.0004355197915664086, validation loss: 0.07956979009840223
# Train accuracy = 0.9692307692307692
# Validation accuracy = 0.3194444444444444
# Epoch 66, training loss: 0.00031507969475709475, validation loss: 0.06974383195241292
# Train accuracy = 0.9807692307692307
# Validation accuracy = 0.3194444444444444
# Epoch 67, training loss: 0.00019120058188071618, validation loss: 0.04772380987803141
# Train accuracy = 0.9884615384615385
# Validation accuracy = 0.3888888888888889
# Epoch 68, training loss: 0.0005144280882982107, validation loss: 0.027339284618695576
# Train accuracy = 0.9384615384615385
# Validation accuracy = 0.5833333333333334
# Epoch 69, training loss: 0.0003390350020848788, validation loss: 0.008603621688154008
# Train accuracy = 0.9653846153846154
# Validation accuracy = 0.8472222222222222
# Epoch 70, training loss: 0.00037089523214560286, validation loss: 0.008726748327414194
# Train accuracy = 0.9653846153846154
# Validation accuracy = 0.8194444444444444
# Epoch 71, training loss: 0.0004725638777017593, validation loss: 0.021265467007954914
# Train accuracy = 0.9423076923076923
# Validation accuracy = 0.6805555555555556
# Epoch 72, training loss: 0.00034566854055111227, validation loss: 0.03286882241566976
# Train accuracy = 0.9538461538461539
# Validation accuracy = 0.5694444444444444
# Epoch 73, training loss: 0.0004382781397837859, validation loss: 0.030924419562021892
# Train accuracy = 0.95
# Validation accuracy = 0.6111111111111112
# Epoch 74, training loss: 0.0004657347901509358, validation loss: 0.018890996774037678
# Train accuracy = 0.9461538461538461
# Validation accuracy = 0.6666666666666666
# Epoch 75, training loss: 0.0002720849445232978, validation loss: 0.009270519018173218
# Train accuracy = 0.9730769230769231
# Validation accuracy = 0.8194444444444444
# Epoch 76, training loss: 0.00040626032994343686, validation loss: 0.005400038841697905
# Train accuracy = 0.9692307692307692
# Validation accuracy = 0.9027777777777778
# Epoch 77, training loss: 0.00033454253123356745, validation loss: 0.00502587937646442
# Train accuracy = 0.9615384615384616
# Validation accuracy = 0.9166666666666666
# Epoch 78, training loss: 0.0006246489401047046, validation loss: 0.0052478015422821045
# Train accuracy = 0.9076923076923077
# Validation accuracy = 0.9027777777777778
# Epoch 79, training loss: 0.00028714454517914697, validation loss: 0.0056531160242027706
# Train accuracy = 0.9615384615384616
# Validation accuracy = 0.8888888888888888
# Epoch 80, training loss: 0.00023263346117276411, validation loss: 0.01289264526632097
# Train accuracy = 0.9769230769230769
# Validation accuracy = 0.6944444444444444
# Epoch 81, training loss: 0.00023405647908265775, validation loss: 0.036555326647228666
# Train accuracy = 0.9769230769230769
# Validation accuracy = 0.4722222222222222
# Epoch 82, training loss: 0.00017697113351180003, validation loss: 0.056419842773013644
# Train accuracy = 0.9807692307692307
# Validation accuracy = 0.375
# Epoch 83, training loss: 0.0003954454969901305, validation loss: 0.05001924104160733
# Train accuracy = 0.9538461538461539
# Validation accuracy = 0.4166666666666667
# Epoch 84, training loss: 0.0002959905908657954, validation loss: 0.07484551270802815
# Train accuracy = 0.9653846153846154
# Validation accuracy = 0.3333333333333333
# Epoch 85, training loss: 0.00034158433286043315, validation loss: 0.06237491634156969
# Train accuracy = 0.9576923076923077
# Validation accuracy = 0.4027777777777778
# Epoch 86, training loss: 0.00040865339911901034, validation loss: 0.027523941463894315
# Train accuracy = 0.9538461538461539
# Validation accuracy = 0.5694444444444444
# Epoch 87, training loss: 0.0005726839487369244, validation loss: 0.01011278728644053
# Train accuracy = 0.95
# Validation accuracy = 0.8611111111111112
# Epoch 88, training loss: 0.0003799494069356185, validation loss: 0.010169641839133369
# Train accuracy = 0.9576923076923077
# Validation accuracy = 0.8611111111111112
# Epoch 89, training loss: 0.0006987553376417893, validation loss: 0.007303223841720157
# Train accuracy = 0.9307692307692308
# Validation accuracy = 0.8611111111111112
# Epoch 90, training loss: 0.0004696184625992408, validation loss: 0.010862490369213952
# Train accuracy = 0.9615384615384616
# Validation accuracy = 0.8333333333333334
# Epoch 91, training loss: 0.0005178878513666299, validation loss: 0.037519226471583046
# Train accuracy = 0.926923076923077
# Validation accuracy = 0.4861111111111111
# Epoch 92, training loss: 0.00047080814838409426, validation loss: 0.05479170878728231
# Train accuracy = 0.95
# Validation accuracy = 0.4027777777777778
# Epoch 93, training loss: 0.0004969101685744065, validation loss: 0.04068701797061496
# Train accuracy = 0.9307692307692308
# Validation accuracy = 0.5
# Epoch 94, training loss: 0.0003176751331641124, validation loss: 0.01967863572968377
# Train accuracy = 0.9692307692307692
# Validation accuracy = 0.625
# Epoch 95, training loss: 0.0004313463201889625, validation loss: 0.005993954837322235
# Train accuracy = 0.9576923076923077
# Validation accuracy = 0.875
# Epoch 96, training loss: 0.0003392683485379586, validation loss: 0.004494273414214452
# Train accuracy = 0.9653846153846154
# Validation accuracy = 0.9027777777777778
# Epoch 97, training loss: 0.0007245568128732534, validation loss: 0.008538185722298093
# Train accuracy = 0.9153846153846154
# Validation accuracy = 0.8611111111111112
# Epoch 98, training loss: 0.000540415312235172, validation loss: 0.014169451263215806
# Train accuracy = 0.9346153846153846
# Validation accuracy = 0.75
# Epoch 99, training loss: 0.0006629473887957059, validation loss: 0.009577280945248075
# Train accuracy = 0.9076923076923077
# Validation accuracy = 0.8333333333333334

# %%
# Testing
correct = 0
predictions = []
cloudy_pred = 0
clear_pred = 0

model = torch.load('best_model.pt')

with torch.no_grad():
    for batch_nr, (data, labels) in enumerate(test_loader):
        
            # predict
            pred = model(data)
            pred = torch.squeeze(pred)
        
            # calculate accuracy
            preds = torch.sigmoid(pred) >= 0.5
            
            for pred in preds:
                predictions.append(pred)

for idx, pred in enumerate(predictions):
    if pred == test_label[idx]:
        correct += 1
        if pred == 1:
            cloudy_pred += 1
        else:
            clear_pred += 1

print("Final accuracy: %.2f%%" % (100*correct/len(test_label)))
print(f'Correct {correct} times out of {len(img_paths_test)}')


total_cloudy = np.sum(test_label)
total_clear = len(test_label)-total_cloudy

print(f'Correct {clear_pred} times out of {total_clear}: {100*clear_pred/total_clear}')
print(f'Correct {cloudy_pred} times out of {total_cloudy}: {100*cloudy_pred/total_cloudy}')

cm = confusion_matrix(test_label, predictions)
ConfusionMatrixDisplay(confusion_matrix = cm,  display_labels=['Clear', 'Cloudy']).plot()
# Out:
# Final accuracy: 89.00%
# Correct 89 times out of 100
# Correct 68 times out of 72: 94.44444444444444
# Correct 21 times out of 28: 75.0
